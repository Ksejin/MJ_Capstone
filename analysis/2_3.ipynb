# %% [markdown]
# <h1>3번. 농산물(고추,마늘,양파) 수입량, 수출량이 가격에 영향을 끼치는가?</h1>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# <h4>월별 수입 수출량 데이터</h4>

# %%
# pepper = pd.read_csv('./데이터/수입수출량/고추_월별_수입수출량.csv') 고추 종류가 너무 많아서 일단 제외
garlic = pd.read_csv('./데이터/수입수출량/마늘_월별_수입수출량.csv', encoding='euc-kr')
onion = pd.read_csv('./데이터/수입수출량/양파_월별_수입수출량.csv', encoding='euc-kr')

# %%
garlic
# Out:
#        년도   월    수출(중량)     수입(중량)
# 0    2010   1    4172.9  1823871.0
# 1    2010   2    8397.0  2388547.0
# 2    2010   3    8147.0  1401952.0
# 3    2010   4    6122.7  3854173.0
# 4    2010   5    5535.0  1697612.0
# ..    ...  ..       ...        ...
# 117  2019  11  273592.4  2037108.7
# 118  2019  12  441897.7  2722370.5
# 119  2020   1  187620.7  4276570.7
# 120  2020   2  582410.2  1436867.4
# 121  2020   3  473373.2  4747189.6
#
# [122 rows x 4 columns]

# %%
onion
# Out:
#        년도   월     수출(중량)     수입(중량)
# 0    2010   1   197804.0   230808.0
# 1    2010   2   120878.1   778786.0
# 2    2010   3    30478.5   297095.0
# 3    2010   4      206.5  6244403.0
# 4    2010   5     2166.0  2038736.0
# ..    ...  ..        ...        ...
# 117  2019  11  1559163.7  3124847.0
# 118  2019  12     1886.0  1446271.9
# 119  2020   1     4290.0  2685336.1
# 120  2020   2    20255.5  2144917.3
# 121  2020   3     1923.0  4193266.9
#
# [122 rows x 4 columns]

# %% [markdown]
# <h4>월별 가격 데이터</h4>

# %%
garlic_price = pd.read_csv('./데이터/KAMIS_가격/마늘_난지_월별_가격.csv')
onion_price = pd.read_csv('./데이터/KAMIS_가격/양파_월별_가격.csv')

# %%
garlic_price
# Out:
#        년도   월    가격
# 0    2010   1  2741
# 1    2010   2  2823
# 2    2010   3  2741
# 3    2010   4  2725
# 4    2010   5  3326
# ..    ...  ..   ...
# 118  2019  11  3341
# 119  2019  12  3320
# 120  2020   1  3300
# 121  2020   2  3214
# 122  2020   3  3216
#
# [123 rows x 3 columns]

# %%
onion_price
# Out:
#        년도   월    가격
# 0    2010   1   603
# 1    2010   2   658
# 2    2010   3   914
# 3    2010   4  1505
# 4    2010   5   959
# ..    ...  ..   ...
# 118  2019  11   605
# 119  2019  12   749
# 120  2020   1   929
# 121  2020   2  1100
# 122  2020   3  1173
#
# [123 rows x 3 columns]

# %% [markdown]
# <h4>월별 데이터</h4>

# %%
garlic_data = pd.merge(garlic, garlic_price,how='left')
pd.set_option('display.max_rows', 200)
garlic_data
# Out:
#        년도   월    수출(중량)      수입(중량)    가격
# 0    2010   1    4172.9   1823871.0  2741
# 1    2010   2    8397.0   2388547.0  2823
# 2    2010   3    8147.0   1401952.0  2741
# 3    2010   4    6122.7   3854173.0  2725
# 4    2010   5    5535.0   1697612.0  3326
# 5    2010   6    6862.2   1049296.0  3492
# 6    2010   7    3575.2   3407075.0  4741
# 7    2010   8   11401.1  12513653.0  5621
# 8    2010   9    2895.4   4811388.0  6337
# 9    2010  10    5377.0   9299402.0  6205
# 10   2010  11    7978.1   7514982.0  5925
# 11   2010  12   20673.9  14246228.0  5709
# 12   2011   1   38563.1   3709989.0  5679
# 106  2018  11    145131.0   5019210.4   699
# 107  2018  12    232240.0   2858362.1   661
# 108  2019   1    821330.0   5571387.2   615
# 109  2019   2    165470.0   3131466.2   605
# 110  2019   3      4730.0   4655135.3   673
# 111  2019   5    912266.0   2304312.0   658
# 112  2019   6  10153040.8   1395607.4   485
# 113  2019   7  20949422.7   2498183.4   423
# 114  2019   8   6308832.7   1317767.7   500
# 115  2019   9   3558273.8   2537696.5   539
# 116  2019  10   5975115.1   1703417.9   521
# 117  2019  11   1559163.7   3124847.0   605
# 118  2019  12      1886.0   1446271.9   749
# 119  2020   1      4290.0   2685336.1   929
# 120  2020   2     20255.5   2144917.3  1100
# 121  2020   3      1923.0   4193266.9  1173

# %% [markdown]
# <h4>연도별 수입 수출량 데이터</h4>

# %%
garlic_year = pd.read_csv('./데이터/수입수출량/마늘_연도별_수입수출량.csv', encoding='euc-kr')
onion_year = pd.read_csv('./데이터/수입수출량/양파_연도별_수입수출량.csv', encoding='euc-kr')

# %%
garlic_year
# Out:
#      년도     수출(중량)      수입(중량)
# 0  2010    91137.5  64008179.0
# 1  2011   113381.5  78619908.0
# 2  2012   916703.2  55253845.0
# 3  2013   449279.6  44507818.0
# 4  2014   127020.3  43399445.0
# 5  2015   227697.9  62193407.0
# 6  2016    76408.5  74493865.0
# 7  2017   115894.4  37016890.1
# 8  2018    86438.8  43315872.8
# 9  2019  2030415.3  42746932.3

# %%
onion_year
# Out:
#      년도      수출(중량)       수입(중량)
# 0  2010   3829171.8   21334085.0
# 1  2011    777198.4   18330617.0
# 2  2012    962210.0   45952057.0
# 3  2013    722700.9   65243477.0
# 4  2014  24272312.0    8553208.0
# 5  2015    385837.8  154369316.0
# 6  2016   8909287.6   55350307.7
# 7  2017    546661.6  159341841.2
# 8  2018   3461571.0   70345663.7
# 9  2019  50419905.3   35058464.7

# %% [markdown]
# <h4>연도별 가격 데이터</h4>

# %%
garlic_year_price = pd.read_csv('./데이터/KAMIS_가격/마늘_난지_연도별_가격.csv')
onion_year_price = pd.read_csv('./데이터/KAMIS_가격/양파_연도별_가격.csv')

# %%
garlic_year_price
# Out:
#      년도  평균가격
# 0  2010  4387
# 1  2011  4434
# 2  2012  4014
# 3  2013  3216
# 4  2014  3062
# 5  2015  4336
# 6  2016  6011
# 7  2017  6087
# 8  2018  5551
# 9  2019  4255

# %%
onion_year_price
# Out:
#      년도  평균가격
# 0  2010   893
# 1  2011   799
# 2  2012   901
# 3  2013  1307
# 4  2014   588
# 5  2015  1063
# 6  2016  1100
# 7  2017  1234
# 8  2018   823
# 9  2019   606

# %% [markdown]
# <h4>연도 데이터</h4>

# %%
garlic_year_data = pd.merge(garlic_year, garlic_year_price, how='left')
garlic_year_data
# Out:
#      년도     수출(중량)      수입(중량)  평균가격
# 0  2010    91137.5  64008179.0  4387
# 1  2011   113381.5  78619908.0  4434
# 2  2012   916703.2  55253845.0  4014
# 3  2013   449279.6  44507818.0  3216
# 4  2014   127020.3  43399445.0  3062
# 5  2015   227697.9  62193407.0  4336
# 6  2016    76408.5  74493865.0  6011
# 7  2017   115894.4  37016890.1  6087
# 8  2018    86438.8  43315872.8  5551
# 9  2019  2030415.3  42746932.3  4255

# %%
onion_year_data = pd.merge(onion_year, onion_year_price, how='left')
onion_year_data
# Out:
#      년도      수출(중량)       수입(중량)  평균가격
# 0  2010   3829171.8   21334085.0   893
# 1  2011    777198.4   18330617.0   799
# 2  2012    962210.0   45952057.0   901
# 3  2013    722700.9   65243477.0  1307
# 4  2014  24272312.0    8553208.0   588
# 5  2015    385837.8  154369316.0  1063
# 6  2016   8909287.6   55350307.7  1100
# 7  2017    546661.6  159341841.2  1234
# 8  2018   3461571.0   70345663.7   823
# 9  2019  50419905.3   35058464.7   606

# %% [markdown]
# <h3>2.3.1) 농산물의 평년 수입량은 가격에 영향을 끼치는가?</h3>

# %% [markdown]
# <h4>마늘</h4>

# %%
x = garlic_year_data['수입(중량)']
y = garlic_year_data['평균가격']

plt.plot(x, y, 'o')
plt.show()

# %%
corr = garlic_year_data[['수입(중량)', '평균가격']].corr(method='pearson')
corr
# Out:
#           수입(중량)      평균가격
# 수입(중량)  1.000000  0.130599
# 평균가격    0.130599  1.000000

# %% [markdown]
# <h4>양파</h4>

# %%
x = onion_year_data['수입(중량)']
y = onion_year_data['평균가격']

plt.plot(x, y, 'o')
plt.show()

# %%
corr = onion_year_data[['수입(중량)', '평균가격']].corr(method='pearson')
corr
# Out:
#         수입(중량)    평균가격
# 수입(중량)  1.0000  0.6491
# 평균가격    0.6491  1.0000

# %% [markdown]
# <h3>2.3.2) 농산물의 평년 수출량은 가격에 영향을 끼치는가?</h3>

# %% [markdown]
# <h4>마늘</h4>

# %%
x = garlic_year_data['수출(중량)']
y = garlic_year_data['평균가격']

plt.plot(x, y, 'o')
plt.show()

# %%
corr = garlic_year_data[['수출(중량)', '평균가격']].corr(method='pearson')
corr
# Out:
#           수출(중량)      평균가격
# 수출(중량)  1.000000 -0.257488
# 평균가격   -0.257488  1.000000

# %% [markdown]
# <h4>양파</h4>

# %%
x = onion_year_data['수출(중량)']
y = onion_year_data['평균가격']

plt.plot(x, y, 'o')
plt.show()

# %%
corr = onion_year_data[['수출(중량)', '평균가격']].corr(method='pearson')
corr
# Out:
#           수출(중량)      평균가격
# 수출(중량)  1.000000 -0.660701
# 평균가격   -0.660701  1.000000

# %% [markdown]
# <h3>2.3.3) 농산물의 월별 수입량이 가격에 영향을 끼치는가?</h3>

# %% [markdown]
# <h4>마늘</h4>

# %%
x = garlic_data['수입(중량)']
y = garlic_data['가격']

plt.plot(x, y, 'o')
plt.show()

# %%
corr = garlic_data[['수입(중량)', '가격']].corr(method='pearson')
corr
# Out:
#           수입(중량)        가격
# 수입(중량)  1.000000  0.290488
# 가격      0.290488  1.000000

# %% [markdown]
# <h4>양파</h4>

# %%
x = onion_data['수입(중량)']
y = onion_data['가격']

plt.plot(x, y, 'o')
plt.show()

# %%
corr = onion_data[['수입(중량)', '가격']].corr(method='pearson')
corr
# Out:
#           수입(중량)        가격
# 수입(중량)  1.000000  0.670443
# 가격      0.670443  1.000000

# %% [markdown]
# <h3>2.3.4) 농산물의 월별 수출량이 가격에 영향을 끼치는가?</h3>

# %% [markdown]
# <h4>마늘</h4>

# %%
x = garlic_data['수출(중량)']
y = garlic_data['가격']

plt.plot(x, y, 'o')
plt.show()

# %%
corr = garlic_data[['수출(중량)', '가격']].corr(method='pearson')
corr
# Out:
#           수출(중량)        가격
# 수출(중량)  1.000000 -0.200681
# 가격     -0.200681  1.000000

# %% [markdown]
# <h4>양파</h4>

# %%
x = onion_data['수출(중량)']
y = onion_data['가격']

plt.plot(x, y, 'o')
plt.show()

# %%
corr = onion_data[['수출(중량)', '가격']].corr(method='pearson')
corr
# Out:
#           수출(중량)        가격
# 수출(중량)  1.000000 -0.340621
# 가격     -0.340621  1.000000
