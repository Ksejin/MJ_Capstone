# %% [markdown]
# <h1>3번. 농산물(고추,마늘,양파) 수입량, 수출량이 가격에 영향을 끼치는가?</h1>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# <h4>월별 수입 수출량 데이터</h4>

# %%
pepper = pd.read_csv('./데이터/수입수출량/고추_월별_수입수출량.csv', encoding='euc-kr')
garlic = pd.read_csv('./데이터/수입수출량/마늘_월별_수입수출량.csv', encoding='euc-kr')
onion = pd.read_csv('./데이터/수입수출량/양파_월별_수입수출량.csv', encoding='euc-kr')

# %%
pepper
# Out:
#        년도   월    수출(중량)      수입(중량)
# 0    2010   1  238133.0  11580818.0
# 1    2010   2  240883.2  14753256.0
# 2    2010   3  250385.4  11453169.0
# 3    2010   4  221121.8  11435557.0
# 4    2010   5  246000.1   9414677.0
# ..    ...  ..       ...         ...
# 117  2019  11  357145.6  27486727.0
# 118  2019  12  266613.6  25596639.6
# 119  2020   1  332080.2  22999655.8
# 120  2020   2  254889.6  14691350.0
# 121  2020   3  436724.2  21919966.0
#
# [122 rows x 4 columns]

# %%
garlic
# Out:
#        년도   월    수출(중량)     수입(중량)
# 0    2010   1    4172.9  1823871.0
# 1    2010   2    8397.0  2388547.0
# 2    2010   3    8147.0  1401952.0
# 3    2010   4    6122.7  3854173.0
# 4    2010   5    5535.0  1697612.0
# ..    ...  ..       ...        ...
# 117  2019  11  273592.4  2037108.7
# 118  2019  12  441897.7  2722370.5
# 119  2020   1  187620.7  4276570.7
# 120  2020   2  582410.2  1436867.4
# 121  2020   3  473373.2  4747189.6
#
# [122 rows x 4 columns]

# %%
onion
# Out:
#        년도   월     수출(중량)     수입(중량)
# 0    2010   1   197804.0   230808.0
# 1    2010   2   120878.1   778786.0
# 2    2010   3    30478.5   297095.0
# 3    2010   4      206.5  6244403.0
# 4    2010   5     2166.0  2038736.0
# ..    ...  ..        ...        ...
# 117  2019  11  1559163.7  3124847.0
# 118  2019  12     1886.0  1446271.9
# 119  2020   1     4290.0  2685336.1
# 120  2020   2    20255.5  2144917.3
# 121  2020   3     1923.0  4193266.9
#
# [122 rows x 4 columns]

# %% [markdown]
# <h4>월별 가격 데이터</h4>

# %%
pepper_yang_price = pd.read_csv('./데이터/KAMIS_가격/건고추_양건_월별_가격.csv')
pepper_hwa_price = pd.read_csv('./데이터/KAMIS_가격/건고추_양건_월별_가격.csv')
garlic_price = pd.read_csv('./데이터/KAMIS_가격/마늘_난지_월별_가격.csv')
onion_price = pd.read_csv('./데이터/KAMIS_가격/양파_월별_가격.csv')

# %%
pepper_yang_price
# Out:
#        년도   월     가격
# 0    2000   1   7972
# 1    2000   2   8293
# 2    2000   3   8433
# 3    2000   4   8375
# 4    2000   5   8367
# ..    ...  ..    ...
# 235  2019   8  20445
# 236  2019   9  19895
# 237  2019  10  18825
# 238  2019  11  18698
# 239  2019  12  18788
#
# [240 rows x 3 columns]

# %%
pepper_hwa_price
# Out:
#        년도   월     가격
# 0    2000   1   7972
# 1    2000   2   8293
# 2    2000   3   8433
# 3    2000   4   8375
# 4    2000   5   8367
# ..    ...  ..    ...
# 235  2019   8  20445
# 236  2019   9  19895
# 237  2019  10  18825
# 238  2019  11  18698
# 239  2019  12  18788
#
# [240 rows x 3 columns]

# %%
garlic_price
# Out:
#        년도   월    가격
# 0    2000   1  1410
# 1    2000   2  1496
# 2    2000   3  1709
# 3    2000   4  1754
# 4    2000   5  1885
# ..    ...  ..   ...
# 235  2019   8  3451
# 236  2019   9  3320
# 237  2019  10  3320
# 238  2019  11  3341
# 239  2019  12  3320
#
# [240 rows x 3 columns]

# %%
onion_price
# Out:
#        년도   월   가격
# 0    2000   1  479
# 1    2000   2  516
# 2    2000   3  744
# 3    2000   4  953
# 4    2000   5  616
# ..    ...  ..  ...
# 235  2019   8  500
# 236  2019   9  539
# 237  2019  10  521
# 238  2019  11  605
# 239  2019  12  749
#
# [240 rows x 3 columns]

# %% [markdown]
# <h4>월별 데이터</h4>

# %%
pepper_yang_data = pd.merge(pepper, pepper_yang_price ,how='left')
pd.set_option('display.max_rows', 200)
pepper_yang_data
# Out:
#        년도   월    수출(중량)      수입(중량)       가격
# 0    2010   1  238133.0  11580818.0  11957.0
# 1    2010   2  240883.2  14753256.0  11900.0
# 2    2010   3  250385.4  11453169.0  11900.0
# 3    2010   4  221121.8  11435557.0  11894.0
# 4    2010   5  246000.1   9414677.0  11833.0
# 5    2010   6  306207.4   8431964.0  11833.0
# 6    2010   7  264389.6   7952871.0  11742.0
# 7    2010   8  204159.4  13631633.0  11851.0
# 8    2010   9  221491.3   4775796.0  12612.0
# 9    2010  10  234747.2  15780670.0  16924.0
# 10   2010  11  281863.2  29318442.0  17545.0
# 11   2010  12  335342.6  17573904.0  17574.0
# 12   2011   1  257566.5  19374578.0  17546.0
# 13   2011   2  174423.1  12395777.0  17676.0
# 14   2011   3  263162.2  17810920.0  17700.0
# 15   2011   4  272274.8  13329196.0  17700.0
# 16   2011   5  247948.8  11858149.0  17647.0
# 17   2011   6  210408.2  11992978.0  17633.0
# 18   2011   7  250387.5  14081004.0  17605.0
# 19   2011   8  184305.1  11828475.0  20274.0
# ...

# %%
pepper_hwa_data = pd.merge(pepper, pepper_hwa_price ,how='left')
pd.set_option('display.max_rows', 200)
pepper_hwa_data
# Out:
#        년도   월    수출(중량)      수입(중량)       가격
# 0    2010   1  238133.0  11580818.0  11957.0
# 1    2010   2  240883.2  14753256.0  11900.0
# 2    2010   3  250385.4  11453169.0  11900.0
# 3    2010   4  221121.8  11435557.0  11894.0
# 4    2010   5  246000.1   9414677.0  11833.0
# 5    2010   6  306207.4   8431964.0  11833.0
# 6    2010   7  264389.6   7952871.0  11742.0
# 7    2010   8  204159.4  13631633.0  11851.0
# 8    2010   9  221491.3   4775796.0  12612.0
# 9    2010  10  234747.2  15780670.0  16924.0
# 10   2010  11  281863.2  29318442.0  17545.0
# 11   2010  12  335342.6  17573904.0  17574.0
# 12   2011   1  257566.5  19374578.0  17546.0
# 13   2011   2  174423.1  12395777.0  17676.0
# 14   2011   3  263162.2  17810920.0  17700.0
# 15   2011   4  272274.8  13329196.0  17700.0
# 16   2011   5  247948.8  11858149.0  17647.0
# 17   2011   6  210408.2  11992978.0  17633.0
# 18   2011   7  250387.5  14081004.0  17605.0
# 19   2011   8  184305.1  11828475.0  20274.0
# ...

# %%
garlic_data = pd.merge(garlic, garlic_price,how='left')
pd.set_option('display.max_rows', 200)
garlic_data
# Out:
#        년도   월    수출(중량)      수입(중량)      가격
# 0    2010   1    4172.9   1823871.0  2741.0
# 1    2010   2    8397.0   2388547.0  2823.0
# 2    2010   3    8147.0   1401952.0  2741.0
# 3    2010   4    6122.7   3854173.0  2725.0
# 4    2010   5    5535.0   1697612.0  3326.0
# 5    2010   6    6862.2   1049296.0  3492.0
# 6    2010   7    3575.2   3407075.0  4741.0
# 7    2010   8   11401.1  12513653.0  5621.0
# 8    2010   9    2895.4   4811388.0  6337.0
# 9    2010  10    5377.0   9299402.0  6205.0
# 10   2010  11    7978.1   7514982.0  5925.0
# 11   2010  12   20673.9  14246228.0  5709.0
# 12   2011   1   38563.1   3709989.0  5679.0
# 13   2011   2     614.4   4658355.0  5813.0
# 14   2011   3   18653.8   9843349.0  5810.0
# 15   2011   4   14900.4   7934083.0  5413.0
# 16   2011   5    3690.4   2544165.0  4705.0
# 17   2011   6    8584.6   3505537.0  4269.0
# 18   2011   7    2962.8  10339192.0  4133.0
# 19   2011   8    5026.6  10681821.0  3375.0
# ...

# %%
onion_data = pd.merge(onion, onion_price,how='left')
pd.set_option('display.max_rows', 200)
onion_data
# Out:
#        년도   월      수출(중량)      수입(중량)      가격
# 0    2010   1    197804.0    230808.0   603.0
# 1    2010   2    120878.1    778786.0   658.0
# 2    2010   3     30478.5    297095.0   914.0
# 3    2010   4       206.5   6244403.0  1505.0
# 4    2010   5      2166.0   2038736.0   959.0
# 5    2010   6   1678795.0    372609.0   627.0
# 6    2010   7   1691399.5    268015.0   770.0
# 7    2010   8    105411.0    441071.0   884.0
# 8    2010   9       328.0    949642.0   938.0
# 9    2010  10       127.0    902210.0   920.0
# 10   2010  11        76.5   2569237.0   938.0
# 11   2010  12      1501.7   6241473.0   927.0
# 12   2011   1       253.0    980564.0  1060.0
# 13   2011   2     25376.0   4334361.0  1353.0
# 14   2011   3      2826.0   4846506.0  1106.0
# 15   2011   4     73060.0   1269880.0   608.0
# 16   2011   5     50017.0    390503.0   486.0
# 17   2011   6    438815.0    200752.0   574.0
# 18   2011   7    127633.0    748470.0   680.0
# ...

# %% [markdown]
# <h4>연도별 수입 수출량 데이터</h4>

# %%
pepper_year = pd.read_csv('./데이터/수입수출량/고추_연도별_수입수출량.csv', encoding='euc-kr')
garlic_year = pd.read_csv('./데이터/수입수출량/마늘_연도별_수입수출량.csv', encoding='euc-kr')
onion_year = pd.read_csv('./데이터/수입수출량/양파_연도별_수입수출량.csv', encoding='euc-kr')

# %%
pepper_year
# Out:
#      년도     수출(중량)       수입(중량)
# 0  2010  3044724.2  156102757.0
# 1  2011  2923670.6  217901269.0
# 2  2012  3410437.5  199752617.0
# 3  2013  3083178.3  173316259.0
# 4  2014  3242493.9  172725457.0
# 5  2015  3137797.2  199157265.0
# 6  2016  2772674.3  204681584.2
# 7  2017  2663991.1  228016343.4
# 8  2018  2951595.6  246212485.5
# 9  2019  3517456.6  244319174.1

# %%
garlic_year
# Out:
#      년도     수출(중량)      수입(중량)
# 0  2010    91137.5  64008179.0
# 1  2011   113381.5  78619908.0
# 2  2012   916703.2  55253845.0
# 3  2013   449279.6  44507818.0
# 4  2014   127020.3  43399445.0
# 5  2015   227697.9  62193407.0
# 6  2016    76408.5  74493865.0
# 7  2017   115894.4  37016890.1
# 8  2018    86438.8  43315872.8
# 9  2019  2030415.3  42746932.3

# %%
onion_year
# Out:
#      년도      수출(중량)       수입(중량)
# 0  2010   3829171.8   21334085.0
# 1  2011    777198.4   18330617.0
# 2  2012    962210.0   45952057.0
# 3  2013    722700.9   65243477.0
# 4  2014  24272312.0    8553208.0
# 5  2015    385837.8  154369316.0
# 6  2016   8909287.6   55350307.7
# 7  2017    546661.6  159341841.2
# 8  2018   3461571.0   70345663.7
# 9  2019  50419905.3   35058464.7

# %% [markdown]
# <h4>연도별 가격 데이터</h4>

# %%
pepper_yang_year_price =  pd.read_csv('./데이터/KAMIS_가격/건고추_앙건_연도별_가격.csv')
pepper_hwa_year_price = pd.read_csv('./데이터/KAMIS_가격/건고추_화건_연도별_가격.csv')
garlic_year_price = pd.read_csv('./데이터/KAMIS_가격/마늘_난지_연도별_가격.csv')
onion_year_price = pd.read_csv('./데이터/KAMIS_가격/양파_연도별_가격.csv')

# %%
pepper_yang_year_price
# Out:
#       년도   평균가격
# 0   2000   8501
# 1   2001   9584
# 2   2002   8256
# 3   2003  10250
# 4   2004  12139
# 5   2005  10106
# 6   2006  10875
# 7   2007  11630
# 8   2008  10490
# 9   2009  11619
# 10  2010  13358
# 11  2011  21567
# 12  2012  25236
# 13  2013  16908
# 14  2014  15152
# 15  2015  16610
# 16  2016  13524
# 17  2017  16555
# 18  2018  23916
# 19  2019  21068

# %%
pepper_hwa_year_price
# Out:
#       년도   평균가격
# 0   2000   7263
# 1   2001   7984
# 2   2002   6480
# 3   2003   7763
# 4   2004   9698
# 5   2005   8118
# 6   2006   8528
# 7   2007   8978
# 8   2008   8541
# 9   2009   9721
# 10  2010  10731
# 11  2011  18099
# 12  2012  20807
# 13  2013  13188
# 14  2014  12263
# 15  2015  13649
# 16  2016  11359
# 17  2017  13692
# 18  2018  20099
# 19  2019  17545

# %%
garlic_year_price
# Out:
#       년도  평균가격
# 0   2000  1636
# 1   2001  1658
# 2   2002  1961
# 3   2003  2155
# 4   2004  2473
# 5   2005  2140
# 6   2006  2080
# 7   2007  2309
# 8   2008  1899
# 9   2009  2049
# 10  2010  4387
# 11  2011  4434
# 12  2012  4014
# 13  2013  3216
# 14  2014  3062
# 15  2015  4336
# 16  2016  6011
# 17  2017  6087
# 18  2018  5551
# 19  2019  4255

# %%
onion_year_price
# Out:
#       년도  평균가격
# 0   2000   576
# 1   2001   460
# 2   2002   402
# 3   2003   916
# 4   2004   621
# 5   2005   576
# 6   2006   770
# 7   2007   551
# 8   2008   718
# 9   2009   819
# 10  2010   893
# 11  2011   799
# 12  2012   901
# 13  2013  1307
# 14  2014   588
# 15  2015  1063
# 16  2016  1100
# 17  2017  1234
# 18  2018   823
# 19  2019   606

# %% [markdown]
# <h4>연도 데이터</h4>

# %%
pepper_yang_year_data = pd.merge(pepper_year, pepper_yang_year_price, how='left')
pepper_yang_year_data
# Out:
#      년도     수출(중량)       수입(중량)   평균가격
# 0  2010  3044724.2  156102757.0  13358
# 1  2011  2923670.6  217901269.0  21567
# 2  2012  3410437.5  199752617.0  25236
# 3  2013  3083178.3  173316259.0  16908
# 4  2014  3242493.9  172725457.0  15152
# 5  2015  3137797.2  199157265.0  16610
# 6  2016  2772674.3  204681584.2  13524
# 7  2017  2663991.1  228016343.4  16555
# 8  2018  2951595.6  246212485.5  23916
# 9  2019  3517456.6  244319174.1  21068

# %%
pepper_hwa_year_data = pd.merge(pepper_year, pepper_hwa_year_price, how='left')
pepper_hwa_year_data
# Out:
#      년도     수출(중량)       수입(중량)   평균가격
# 0  2010  3044724.2  156102757.0  10731
# 1  2011  2923670.6  217901269.0  18099
# 2  2012  3410437.5  199752617.0  20807
# 3  2013  3083178.3  173316259.0  13188
# 4  2014  3242493.9  172725457.0  12263
# 5  2015  3137797.2  199157265.0  13649
# 6  2016  2772674.3  204681584.2  11359
# 7  2017  2663991.1  228016343.4  13692
# 8  2018  2951595.6  246212485.5  20099
# 9  2019  3517456.6  244319174.1  17545

# %%
garlic_year_data = pd.merge(garlic_year, garlic_year_price, how='left')
garlic_year_data
# Out:
#      년도     수출(중량)      수입(중량)  평균가격
# 0  2010    91137.5  64008179.0  4387
# 1  2011   113381.5  78619908.0  4434
# 2  2012   916703.2  55253845.0  4014
# 3  2013   449279.6  44507818.0  3216
# 4  2014   127020.3  43399445.0  3062
# 5  2015   227697.9  62193407.0  4336
# 6  2016    76408.5  74493865.0  6011
# 7  2017   115894.4  37016890.1  6087
# 8  2018    86438.8  43315872.8  5551
# 9  2019  2030415.3  42746932.3  4255

# %%
onion_year_data = pd.merge(onion_year, onion_year_price, how='left')
onion_year_data
# Out:
#      년도      수출(중량)       수입(중량)  평균가격
# 0  2010   3829171.8   21334085.0   893
# 1  2011    777198.4   18330617.0   799
# 2  2012    962210.0   45952057.0   901
# 3  2013    722700.9   65243477.0  1307
# 4  2014  24272312.0    8553208.0   588
# 5  2015    385837.8  154369316.0  1063
# 6  2016   8909287.6   55350307.7  1100
# 7  2017    546661.6  159341841.2  1234
# 8  2018   3461571.0   70345663.7   823
# 9  2019  50419905.3   35058464.7   606

# %% [markdown]
# <h3>2.3.1) 농산물의 평년 수입량은 가격에 영향을 끼치는가?</h3>

# %% [markdown]
# <h4>고추</h4>

# %%
x = pepper_yang_year_data['수입(중량)']
y = pepper_yang_year_data['평균가격']

plt.plot(x, y, 'o')
plt.show()

# %%
corr = pepper_yang_year_data[['수입(중량)', '평균가격']].corr(method='pearson')
corr
# Out:
#           수입(중량)      평균가격
# 수입(중량)  1.000000  0.601813
# 평균가격    0.601813  1.000000

# %%
x = pepper_hwa_year_data['수입(중량)']
y = pepper_hwa_year_data['평균가격']

plt.plot(x, y, 'o')
plt.show()

# %%
corr = pepper_hwa_year_data[['수입(중량)', '평균가격']].corr(method='pearson')
corr
# Out:
#           수입(중량)      평균가격
# 수입(중량)  1.000000  0.646675
# 평균가격    0.646675  1.000000

# %% [markdown]
# <h4>마늘</h4>

# %%
x = garlic_year_data['수입(중량)']
y = garlic_year_data['평균가격']

plt.plot(x, y, 'o')
plt.show()

# %%
corr = garlic_year_data[['수입(중량)', '평균가격']].corr(method='pearson')
corr
# Out:
#           수입(중량)      평균가격
# 수입(중량)  1.000000  0.130599
# 평균가격    0.130599  1.000000

# %% [markdown]
# <h4>양파</h4>

# %%
x = onion_year_data['수입(중량)']
y = onion_year_data['평균가격']

plt.plot(x, y, 'o')
plt.show()

# %%
corr = onion_year_data[['수입(중량)', '평균가격']].corr(method='pearson')
corr
# Out:
#         수입(중량)    평균가격
# 수입(중량)  1.0000  0.6491
# 평균가격    0.6491  1.0000

# %% [markdown]
# <h3>2.3.2) 농산물의 평년 수출량은 가격에 영향을 끼치는가?</h3>

# %% [markdown]
# <h4>고추</h4>

# %%
x = pepper_yang_year_data['수출(중량)']
y = pepper_yang_year_data['평균가격']

plt.plot(x, y, 'o')
plt.show()

# %%
corr = pepper_yang_year_data[['수출(중량)', '평균가격']].corr(method='pearson')
corr
# Out:
#           수출(중량)      평균가격
# 수출(중량)  1.000000  0.394793
# 평균가격    0.394793  1.000000

# %%
x = pepper_hwa_year_data['수출(중량)']
y = pepper_hwa_year_data['평균가격']

plt.plot(x, y, 'o')
plt.show()

# %%
corr = pepper_hwa_year_data[['수출(중량)', '평균가격']].corr(method='pearson')
corr
# Out:
#           수출(중량)      평균가격
# 수출(중량)  1.000000  0.361491
# 평균가격    0.361491  1.000000

# %% [markdown]
# <h4>마늘</h4>

# %%
x = garlic_year_data['수출(중량)']
y = garlic_year_data['평균가격']

plt.plot(x, y, 'o')
plt.show()

# %%
corr = garlic_year_data[['수출(중량)', '평균가격']].corr(method='pearson')
corr
# Out:
#           수출(중량)      평균가격
# 수출(중량)  1.000000 -0.257488
# 평균가격   -0.257488  1.000000

# %% [markdown]
# <h4>양파</h4>

# %%
x = onion_year_data['수출(중량)']
y = onion_year_data['평균가격']

plt.plot(x, y, 'o')
plt.show()

# %%
corr = onion_year_data[['수출(중량)', '평균가격']].corr(method='pearson')
corr
# Out:
#           수출(중량)      평균가격
# 수출(중량)  1.000000 -0.660701
# 평균가격   -0.660701  1.000000

# %% [markdown]
# <h3>2.3.3) 농산물의 월별 수입량이 가격에 영향을 끼치는가?</h3>

# %% [markdown]
# <h4>고추</h4>

# %%
x = pepper_yang_data['수입(중량)']
y = pepper_yang_data['가격']

plt.plot(x, y, 'o')
plt.show()

# %%
corr = pepper_yang_data[['수입(중량)', '가격']].corr(method='pearson')
corr
# Out:
#           수입(중량)        가격
# 수입(중량)  1.000000  0.422438
# 가격      0.422438  1.000000

# %%
x = pepper_hwa_data['수입(중량)']
y = pepper_hwa_data['가격']

plt.plot(x, y, 'o')
plt.show()

# %%
corr = pepper_hwa_data[['수입(중량)', '가격']].corr(method='pearson')
corr
# Out:
#           수입(중량)        가격
# 수입(중량)  1.000000  0.422438
# 가격      0.422438  1.000000

# %% [markdown]
# <h4>마늘</h4>

# %%
x = garlic_data['수입(중량)']
y = garlic_data['가격']

plt.plot(x, y, 'o')
plt.show()

# %%
corr = garlic_data[['수입(중량)', '가격']].corr(method='pearson')
corr
# Out:
#           수입(중량)        가격
# 수입(중량)  1.000000  0.286262
# 가격      0.286262  1.000000

# %% [markdown]
# <h4>양파</h4>

# %%
x = onion_data['수입(중량)']
y = onion_data['가격']

plt.plot(x, y, 'o')
plt.show()

# %%
corr = onion_data[['수입(중량)', '가격']].corr(method='pearson')
corr
# Out:
#           수입(중량)        가격
# 수입(중량)  1.000000  0.675349
# 가격      0.675349  1.000000

# %% [markdown]
# <h3>2.3.4) 농산물의 월별 수출량이 가격에 영향을 끼치는가?</h3>

# %% [markdown]
# <h4>고추</h4>

# %%
x = pepper_yang_data['수출(중량)']
y = pepper_yang_data['가격']

plt.plot(x, y, 'o')
plt.show()

# %%
corr = pepper_yang_data[['수출(중량)', '가격']].corr(method='pearson')
corr
# Out:
#           수출(중량)        가격
# 수출(중량)  1.000000  0.091732
# 가격      0.091732  1.000000

# %%
x = pepper_hwa_data['수출(중량)']
y = pepper_hwa_data['가격']

plt.plot(x, y, 'o')
plt.show()

# %%
corr = pepper_hwa_data[['수출(중량)', '가격']].corr(method='pearson')
corr
# Out:
#           수출(중량)        가격
# 수출(중량)  1.000000  0.091732
# 가격      0.091732  1.000000

# %% [markdown]
# <h4>마늘</h4>

# %%
x = garlic_data['수출(중량)']
y = garlic_data['가격']

plt.plot(x, y, 'o')
plt.show()

# %%
corr = garlic_data[['수출(중량)', '가격']].corr(method='pearson')
corr
# Out:
#           수출(중량)        가격
# 수출(중량)  1.000000 -0.144049
# 가격     -0.144049  1.000000

# %% [markdown]
# <h4>양파</h4>

# %%
x = onion_data['수출(중량)']
y = onion_data['가격']

plt.plot(x, y, 'o')
plt.show()

# %%
corr = onion_data[['수출(중량)', '가격']].corr(method='pearson')
corr
# Out:
#           수출(중량)        가격
# 수출(중량)  1.000000 -0.339113
# 가격     -0.339113  1.000000
