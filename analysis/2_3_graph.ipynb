# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib inline

rc('font', family='AppleGothic')
plt.rcParams['axes.unicode_minus'] = False

# %%
pepper_year = pd.read_csv('./데이터/수입수출량/고추_연도별_수입수출량.csv', encoding='euc-kr')
garlic_year = pd.read_csv('./데이터/수입수출량/마늘_연도별_수입수출량.csv', encoding='euc-kr')
onion_year = pd.read_csv('./데이터/수입수출량/양파_연도별_수입수출량.csv', encoding='euc-kr')

# %%
pepper = pd.read_csv('./데이터/수입수출량/고추_월별_수입수출량.csv', encoding='euc-kr')
garlic = pd.read_csv('./데이터/수입수출량/마늘_월별_수입수출량.csv', encoding='euc-kr')
onion = pd.read_csv('./데이터/수입수출량/양파_월별_수입수출량.csv', encoding='euc-kr')

# %%
pepper
# Out:
#        년도   월    수출(중량)      수입(중량)
# 0    2010   1  238133.0  11580818.0
# 1    2010   2  240883.2  14753256.0
# 2    2010   3  250385.4  11453169.0
# 3    2010   4  221121.8  11435557.0
# 4    2010   5  246000.1   9414677.0
# ..    ...  ..       ...         ...
# 117  2019  11  357145.6  27486727.0
# 118  2019  12  266613.6  25596639.6
# 119  2020   1  332080.2  22999655.8
# 120  2020   2  254889.6  14691350.0
# 121  2020   3  436724.2  21919966.0
#
# [122 rows x 4 columns]

# %%
# bar_width = 0.3
# alpha = 0.5
# plt.figure(figsize=(20,15))

# plt.bar(pepper_year['년도'], pepper_year['수입(중량)'], 
#              bar_width, 
#              color='r', 
#              label='수입')



# plt.title('고추 수입수출량', fontsize=20)
# plt.ylabel('중량', fontsize=18)
# plt.xlabel('년도', fontsize=18)
# # plt.legend((p1[0], p2[0]), ('수출', '수입'), fontsize=15)

# plt.show()


fig=plt.figure(figsize=(20,15))
ax = fig.add_axes([0,0,1,1])
ax.bar(X + 0.00, pepper_year['수출(중량)'], color = 'b', width = 0.25)
ax.bar(X + 0.25, pepper_year['수입(중량)'], color = 'g', width = 0.25)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-19d53cd6c23b> in <module>
#      20 fig=plt.figure(figsize=(20,15))
#      21 ax = fig.add_axes([0,0,1,1])
# ---> 22 ax.bar(X + 0.00, pepper_year['수출(중량)'], color = 'b', width = 0.25)
#      23 ax.bar(X + 0.25, pepper_year['수입(중량)'], color = 'g', width = 0.25)
#      24 plt.show()
#
# NameError: name 'X' is not defined
