# %%
import pandas as pd
import seaborn as sns
w = pd.read_csv('./weather_0020.csv')
w = w[w.columns.difference(['적설량'])]
w.head()
# Out:
#    month  year       강수량  순간최대풍속         습도   운량       일사량      일조시간 지역(시)  \
# 0      1  2000  1.853871     0.0  67.229032  0.0  1.729032  4.809677   강원도
# 1      1  2000  1.743011     0.0  65.440860  0.0  2.182796  4.956989   경기도
# 2      1  2000  0.685305     0.0  56.602151  0.0  0.620072  5.483871  경상남도
# 3      1  2000  1.475953     0.0  62.008798  0.0  0.985337  4.448680  경상북도
# 4      1  2000  1.087097     0.0  67.225806  0.0  5.741935  3.709677    광주
#
#        최고기온      최저기온      평균기온
# 0  1.704839 -7.463871 -3.057097
# 1  2.120430 -6.701075 -2.425806
# 2  7.167742 -3.006810  1.725806
# 3  4.784751 -4.504106 -0.075367
# 4  5.325806 -2.609677  0.983871

# %%
weather_location = []
location = ['강원도','경기도','경상남도','경상북도','광주','대구','대전','부산','울산','인천','전라남도','전라북도','서울', '제주특별자치도', '충청남도','충청북도']

weather_list = []
# prod_list = []
for i in location:
#     prod_list.append(df[df['연도별']==i].reset_index(drop=True))
#     weather_list.append(w[w['year']==int(i)].reset_index(drop=True))
    weather_list.append(w[w['지역(시)']==i].reset_index(drop=True))
weather_list[0].head()
# prod_list[1]
# Out:
#    month  year       강수량  순간최대풍속         습도   운량       일사량      일조시간 지역(시)  \
# 0      1  2000  1.853871     0.0  67.229032  0.0  1.729032  4.809677   강원도
# 1      2  2000  0.235517     0.0  53.837931  0.0  3.537931  7.079310   강원도
# 2      3  2000  0.438065     0.0  51.009677  0.0  4.393548  6.835484   강원도
# 3      4  2000  1.246000     0.0  52.553333  0.0  5.076667  6.493333   강원도
# 4      5  2000  2.514194     0.0  68.474194  0.0  5.141935  5.554839   강원도
#
#         최고기온       최저기온       평균기온
# 0   1.704839  -7.463871  -3.057097
# 1   2.502759  -9.019310  -3.260000
# 2  10.831290  -1.519355   4.460000
# 3  16.296000   3.520000   9.905333
# 4  21.734194  10.143871  15.491935

# %%
year_list = []
month_list = []
year = 2000
for i in range(20):
    for j in range(1,13):
        year_list.append(year)
        month_list.append(j)
    year += 1
price_a = pd.read_csv('./건고추_양건_월별_가격.csv')
price_b = pd.read_csv('./마늘_난지_월별_가격.csv')
price_c = pd.read_csv('./양파_월별_가격.csv')
price_d = pd.DataFrame(data={'년도': year_list, '월':month_list, '가격':[10318,11296,9612,9163,6271,4462,5204,6141,8240,8045,4826,4229,4043,3935,4000,3388,4705,6752,12251,11513,7264,4103,2911,3448,3365,3051,2864,3842,6650,6929,6624,7463,11805,8694,8050,10700,10184,9908,13403,13616,8292,4043,3834,3866,7666,10630,9855,7480,4517,4062,4502,4333,3237,5415,11356,24381,16905,7148,4263,3342,3366,3071,2511,4634,5173,4816,9135,10037,14582,14230,11936,10615,7947,8472,8705,7795,6297,6880,7133,11247,14485,7305,4316,3824,3173,3583,4419,5379,5429,11419,10794,9769,11501,15244,13710,11509,7545,5764,6242,5817,5434,4925,4840,6903,6086,5629,6015,5704,6188,6180,5935,6078,7492,5692,6423,7014,7033,6657,6295,5785,5734,6926,8596,12727,15305,14484,19164,20736,22737,28461,17418,15165,10265,10419,12536,11101,8337,5311,10924,24445,14590,7692,5295,5013,5421,7490,8297,7850,9205,10535,13118,9845,13012,16648,13168,13541,9545,8954,8650,8909,14185,13679,11017,13562,14311,8857,7833,7062,6650,6188,6657,7320,7806,7780,8245,8853,9589,8868,7380,7384,6805,7682,7755,7727,8367,11412,15461,10946,7135,6515,7341,7345,8510,10822,12100,15910,14465,9227,10276,13136,20168,22976,13830,20962,16500,14790,12755,12216,11937,8295,10686,17705,14324,7091,6618,7234,7088,13589,15114,16371,18990,9831,13700,22318,20682,10943,6512,5979,5968,6276,5545,6106,7285,7478,7115,6914,10563,17638,17481,21660]})
price_e = pd.DataFrame(data={'년도': year_list, '월':month_list, '가격':[6192,8154,8522,7832,4058,2901,4466,4534,5997,4995,2680,2162,2552,2822,3540,3890,2638,6023,6633,7108,6098,3797,2323,3046,3125,2614,2284,2153,3098,3300,3611,6888,8710,4942,4062,6918,7161,7333,10429,9860,6524,3608,5182,6529,8361,8474,5988,3871,2964,2709,3542,4162,3270,3400,6549,12057,8607,3951,2776,2485,2398,2887,3187,3579,3090,2961,4792,5883,9085,9937,6755,7106,6105,6778,8398,7942,5986,3340,4035,9534,10704,3839,3020,3495,2781,2287,2679,3102,2705,3991,5813,6057,9648,9480,7914,6309,4740,4667,4691,5193,3951,3461,3430,6183,5204,3732,3970,3810,3911,3960,6236,11552,9942,4270,4870,6848,6855,4357,3527,3647,4913,7979,11327,13859,9453,6186,8965,9291,19516,15726,9216,11174,13310,12259,13105,8176,3794,3352,6729,10895,8995,5865,3645,3219,3500,5245,9210,12140,7262,4918,7945,9018,12790,9952,7900,10816,12182,12358,12400,11243,6938,5289,6287,13424,12511,5636,5586,5024,4623,4074,3604,3564,3369,3907,6010,7684,8042,4970,4172,3838,3800,4153,4850,4991,8978,7468,6448,6670,6110,4424,4445,4333,5520,8228,12005,15079,11430,6248,7505,15236,21042,10630,8473,9305,10110,10065,9468,7775,4297,4895,8459,15211,17419,7251,6074,6497,6828,9109,8733,8176,6406,5728,10402,18682,15165,8468,7468,6168,4848,4020,3735,3414,3904,5746,7365,8771,14847,15600,9671,9890]})
    
for i in range(len(weather_list)):
    weather_list[i] = weather_list[i][:-4]
    weather_list[i] = weather_list[i][24:]
    weather_list[i] = weather_list[i]
    weather_list[i]['건고추']  =  price_a['가격'][24:]
    weather_list[i]['마늘']  =  price_b['가격'][24:]
    weather_list[i]['양파']  =  price_c['가격'][24:]
    weather_list[i]['배추']  =  price_d['가격'][24:]
    weather_list[i]['무']  =  price_e['가격'][24:]
    print(len(weather_list[i]))
weather_list[1].head()
# Out:
# 216
# 216
# 216
# 216
# 216
# 216
# 216
# 216
# 216
# 216
# 216
# 216
# 216
# 216
# 216
# 216
#     month  year       강수량    순간최대풍속         습도        운량       일사량      일조시간  \
# 24      1  2002  1.529677  7.138710  66.548387  2.509677  1.606452  5.251613
# 25      2  2002  0.069286  7.028571  58.857143  2.385714  2.185714  6.371429
# 26      3  2002  0.940000  8.720000  57.212903  2.948387  2.832258  6.858065
# 27      4  2002  5.239333  8.301333  56.740000  2.720000  3.606667  7.973333
# 28      5  2002  2.333548  6.678710  64.219355  3.238710  3.909677  7.896774
#
#    지역(시)       최고기온       최저기온       평균기온   건고추    마늘   양파    배추     무
# 24   경기도   3.396774  -6.393548  -1.609032  9387  1847  450  3365  3125
# 25   경기도   6.997857  -5.260714   0.455000  9427  2200  443  3051  2614
# 26   경기도  13.434839   0.065161   6.440000  9295  2321  392  2864  2284
# 27   경기도  19.636667   5.899333  12.671333  8556  2288  319  3842  2153
# 28   경기도  23.640645  11.032258  16.930968  7839  2140  288  6650  3098

# %%
years = ['2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012','2013','2014','2015','2016', '2017','2018','2019']
divide_by_year = []
for i in years:
    divide_by_year.append(weather_list[1][weather_list[1]['year']==int(i)].reset_index(drop=True))
divide_by_year[1]
# Out:
#     month  year        강수량    순간최대풍속         습도        운량       일사량      일조시간  \
# 0       1  2003   0.327097  4.821935  66.993548  2.322581  1.696774  5.374194
# 1       2  2003   1.446429  4.657143  67.821429  2.942857  2.042857  5.292857
# 2       3  2003   0.967097  5.687742  62.793548  3.361290  2.593548  6.012903
# 3       4  2003   5.360000  6.707333  63.320000  3.393333  3.000000  5.893333
# 4       5  2003   2.932258  5.952258  63.309677  2.683871  3.909677  8.012903
# 5       6  2003   5.875333  6.210667  72.806667  4.073333  3.086667  5.460000
# 6       7  2003  11.956129  5.949677  78.645161  4.464516  2.903226  4.858065
# 7       8  2003  14.196774  6.076774  81.838710  4.406452  2.483871  4.070968
# 8       9  2003   9.937333  5.862667  79.326667  3.813333  2.586667  4.866667
# 9      10  2003   1.249032  6.850323  68.083871  2.090323  2.677419  6.967742
# 10     11  2003   1.970667  6.013333  70.553333  3.253333  1.520000  4.280000
# 11     12  2003   0.246452  6.666452  63.729032  1.909677  1.638710  5.741935
#
#    지역(시)       최고기온       최저기온       평균기온    건고추    마늘    양파     배추      무
# 0    경기도   0.829032  -9.746452  -4.717419   8264  1889   774  10184   7161
# 1    경기도   6.374286  -4.516429   0.581429   8522  2100  1054   9908   7333
# 2    경기도  11.192258  -0.382581   5.077419   8807  2227  1737  13403  10429
# 3    경기도  18.504000   6.137333  11.976000   8557  2302  1337  13616   9860
# 4    경기도  25.439355  11.954839  18.372903   8521  2218   699   8292   6524
# 5    경기도  26.208667  16.632000  21.008000   8911  2007   519   4043   3608
# 6    경기도  28.063871  19.753548  23.474839   9247  1879   600   3834   5182
# 7    경기도  28.114839  20.431613  23.638710  10016  1912   731   3866   6529
# 8    경기도  25.108000  15.918000  19.908000  12687  2194   858   7666   8361
# 9    경기도  19.089032   5.841935  11.850323  13144  2271   874  10630   8474
# 10   경기도  13.294000   2.962000   7.786667  13033  2330   889   9855   5988
# 11   경기도   4.363871  -5.848387  -1.026452  13051  2524   921   7480   3871

# %%
result = []
for i in range(len(divide_by_year)):
    w = divide_by_year[i]
    print(w.columns.difference(['year']))
    w = w[w.columns.difference(['year'])]
    result.append(w)
corr_list = []
for i in result:
    df = i.corr()
    corr_list.append(df)
corr_list[1]
# Out:
# Index(['month', '강수량', '건고추', '마늘', '무', '배추', '순간최대풍속', '습도', '양파', '운량',
#        '일사량', '일조시간', '지역(시)', '최고기온', '최저기온', '평균기온'],
#       dtype='object')
# Index(['month', '강수량', '건고추', '마늘', '무', '배추', '순간최대풍속', '습도', '양파', '운량',
#        '일사량', '일조시간', '지역(시)', '최고기온', '최저기온', '평균기온'],
#       dtype='object')
# Index(['month', '강수량', '건고추', '마늘', '무', '배추', '순간최대풍속', '습도', '양파', '운량',
#        '일사량', '일조시간', '지역(시)', '최고기온', '최저기온', '평균기온'],
#       dtype='object')
# Index(['month', '강수량', '건고추', '마늘', '무', '배추', '순간최대풍속', '습도', '양파', '운량',
#        '일사량', '일조시간', '지역(시)', '최고기온', '최저기온', '평균기온'],
#       dtype='object')
# Index(['month', '강수량', '건고추', '마늘', '무', '배추', '순간최대풍속', '습도', '양파', '운량',
#        '일사량', '일조시간', '지역(시)', '최고기온', '최저기온', '평균기온'],
#       dtype='object')
# Index(['month', '강수량', '건고추', '마늘', '무', '배추', '순간최대풍속', '습도', '양파', '운량',
#        '일사량', '일조시간', '지역(시)', '최고기온', '최저기온', '평균기온'],
#       dtype='object')
# Index(['month', '강수량', '건고추', '마늘', '무', '배추', '순간최대풍속', '습도', '양파', '운량',
#        '일사량', '일조시간', '지역(시)', '최고기온', '최저기온', '평균기온'],
#       dtype='object')
# Index(['month', '강수량', '건고추', '마늘', '무', '배추', '순간최대풍속', '습도', '양파', '운량',
#        '일사량', '일조시간', '지역(시)', '최고기온', '최저기온', '평균기온'],
#       dtype='object')
# Index(['month', '강수량', '건고추', '마늘', '무', '배추', '순간최대풍속', '습도', '양파', '운량',
#        '일사량', '일조시간', '지역(시)', '최고기온', '최저기온', '평균기온'],
#       dtype='object')
# Index(['month', '강수량', '건고추', '마늘', '무', '배추', '순간최대풍속', '습도', '양파', '운량',
#        '일사량', '일조시간', '지역(시)', '최고기온', '최저기온', '평균기온'],
#       dtype='object')
# Index(['month', '강수량', '건고추', '마늘', '무', '배추', '순간최대풍속', '습도', '양파', '운량',
#        '일사량', '일조시간', '지역(시)', '최고기온', '최저기온', '평균기온'],
#       dtype='object')
# Index(['month', '강수량', '건고추', '마늘', '무', '배추', '순간최대풍속', '습도', '양파', '운량',
#        '일사량', '일조시간', '지역(시)', '최고기온', '최저기온', '평균기온'],
#       dtype='object')
# Index(['month', '강수량', '건고추', '마늘', '무', '배추', '순간최대풍속', '습도', '양파', '운량',
#        '일사량', '일조시간', '지역(시)', '최고기온', '최저기온', '평균기온'],
#       dtype='object')
# Index(['month', '강수량', '건고추', '마늘', '무', '배추', '순간최대풍속', '습도', '양파', '운량',
#        '일사량', '일조시간', '지역(시)', '최고기온', '최저기온', '평균기온'],
#       dtype='object')
# Index(['month', '강수량', '건고추', '마늘', '무', '배추', '순간최대풍속', '습도', '양파', '운량',
#        '일사량', '일조시간', '지역(시)', '최고기온', '최저기온', '평균기온'],
#       dtype='object')
# Index(['month', '강수량', '건고추', '마늘', '무', '배추', '순간최대풍속', '습도', '양파', '운량',
#        '일사량', '일조시간', '지역(시)', '최고기온', '최저기온', '평균기온'],
#       dtype='object')
# Index(['month', '강수량', '건고추', '마늘', '무', '배추', '순간최대풍속', '습도', '양파', '운량',
#        '일사량', '일조시간', '지역(시)', '최고기온', '최저기온', '평균기온'],
#       dtype='object')
# Index(['month', '강수량', '건고추', '마늘', '무', '배추', '순간최대풍속', '습도', '양파', '운량',
#        '일사량', '일조시간', '지역(시)', '최고기온', '최저기온', '평균기온'],
#       dtype='object')
#            month       강수량       건고추        마늘         무        배추    순간최대풍속  \
# month   1.000000  0.178468  0.903307  0.488316 -0.400878 -0.345596  0.682552
# 강수량     0.178468  1.000000 -0.060747 -0.536818 -0.129836 -0.667544  0.144514
# 건고추     0.903307 -0.060747  1.000000  0.575516 -0.151414 -0.056241  0.502948
# 마늘      0.488316 -0.536818  0.575516  1.000000  0.124365  0.496639  0.517491
# 무      -0.400878 -0.129836 -0.151414  0.124365  1.000000  0.778513 -0.087383
# 배추     -0.345596 -0.667544 -0.056241  0.496639  0.778513  1.000000 -0.061168
# 순간최대풍속  0.682552  0.144514  0.502948  0.517491 -0.087383 -0.061168  1.000000
# 습도      0.310083  0.869634  0.186139 -0.583407 -0.274218 -0.744732 -0.034507
# 양파     -0.305754 -0.383979 -0.118771  0.430261  0.765617  0.816666 -0.029323
# 운량     -0.043460  0.854175 -0.271272 -0.568725 -0.073968 -0.521895 -0.026424
# 일사량    -0.204058  0.331202 -0.415637 -0.163418  0.131739 -0.148077  0.285607
# 일조시간   -0.182899 -0.500016 -0.163281  0.350154  0.209199  0.366116  0.227578
# 최고기온    0.256568  0.788223 -0.018557 -0.307323 -0.107852 -0.557569  0.417429
# 최저기온    0.280363  0.865341 -0.004489 -0.379098 -0.181902 -0.652226  0.363254
# 평균기온    0.266506  0.829546 -0.016856 -0.345604 -0.149518 -0.608742  0.390011
#
#               습도        양파        운량       일사량      일조시간      최고기온      최저기온  \
# month   0.310083 -0.305754 -0.043460 -0.204058 -0.182899  0.256568  0.280363
# 강수량     0.869634 -0.383979  0.854175  0.331202 -0.500016  0.788223  0.865341
# 건고추     0.186139 -0.118771 -0.271272 -0.415637 -0.163281 -0.018557 -0.004489
# 마늘     -0.583407  0.430261 -0.568725 -0.163418  0.350154 -0.307323 -0.379098
# 무      -0.274218  0.765617 -0.073968  0.131739  0.209199 -0.107852 -0.181902
# 배추     -0.744732  0.816666 -0.521895 -0.148077  0.366116 -0.557569 -0.652226
# 순간최대풍속 -0.034507 -0.029323 -0.026424  0.285607  0.227578  0.417429  0.363254
# 습도      1.000000 -0.546614  0.739072  0.004667 -0.678307  0.613387  0.721725
# 양파     -0.546614  1.000000 -0.172752 -0.122694  0.129062 -0.411757 -0.455952
# 운량      0.739072 -0.172752  1.000000  0.319347 -0.569295  0.707925  0.784813
# 일사량     0.004667 -0.122694  0.319347  1.000000  0.582031  0.734788  0.637167
# 일조시간   -0.678307  0.129062 -0.569295  0.582031  1.000000 -0.009137 -0.160221
# 최고기온    0.613387 -0.411757  0.707925  0.734788 -0.009137  1.000000  0.985492
# 최저기온    0.721725 -0.455952  0.784813  0.637167 -0.160221  0.985492  1.000000
# 평균기온    0.667833 -0.436349  0.751396  0.690154 -0.085054  0.996210  0.996422
#
#             평균기온
# month   0.266506
# 강수량     0.829546
# 건고추    -0.016856
# 마늘     -0.345604
# 무      -0.149518
# 배추     -0.608742
# 순간최대풍속  0.390011
# 습도      0.667833
# 양파     -0.436349
# 운량      0.751396
# 일사량     0.690154
# 일조시간   -0.085054
# 최고기온    0.996210
# 최저기온    0.996422
# 평균기온    1.000000

# %%
sns.clustermap(corr_list[1], 
               annot = True,      # 실제 값 화면에 나타내기
               cmap = 'RdYlBu_r',  # Red, Yellow, Blue 색상으로 표시
               vmin = -1, vmax = 1, #컬러차트 -1 ~ 1 범위로 표시
              )
# [출처] 상관관계 분석 시각화 - correlation matrix (df.corr, sns.heatmap)|작성자 데이터공방
